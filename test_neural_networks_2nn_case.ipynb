# %% [markdown]
# # Accuracy optimization of the DFT U-net

# %% [markdown]
# We demonstrate that a pure scalability can be reached for both the 1nn and 2nn system. However we can reach accuracies that can be considered low (rel err$=10^{-3}$). For this reason we wonder if we can force the CNN to outperform by increasing the learning capacity in both hidden channels, kernel size and convolutional blocks (without pooling).
#
# We consider the 2nn case in the critical point and two datasets with $1.5 \cdot 10^3$ and $1.5 \cdot 10^4$ sample.

# %% [markdown]
# #### Imports

# %%
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import test_models_unet

# %% [markdown]
# ## Case a) U-Net with pooling incresing the number of Hidden channels

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_5_ks_2_ps_2_nconv_0_nblock','2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 80]_hc_5_ks_2_ps_2_nconv_0_nblock','2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 160]_hc_5_ks_2_ps_2_nconv_0_nblock']

data_path=['data/dataset_2nn/test_unet_periodic_2nn_16_l_5.44_h_100_n.npz']*3

hc=[20,40,80]

ls=[128]*3

# %% [markdown]
# #### Accuracy analysis

# %%
r,de,devde=test_models_unet(models_name=models_name,data_path=data_path)
# Out:
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 20, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(20, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(40, 20, kernel_size=(6,), stride=(2,), padding=(2,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(20, 1, kernel_size=(6,), stride=(2,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=9101
# R_square_test=0.9998987913131714 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_5_ks_2_ps_2_nconv_0_nblock
#
# de=0.0019747847975873515 std(de)=0.00021668540827310076
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(80, 40, kernel_size=(6,), stride=(2,), padding=(2,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(40, 1, kernel_size=(6,), stride=(2,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=35801
# R_square_test=0.9999830722808838 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 80]_hc_5_ks_2_ps_2_nconv_0_nblock
#
# de=0.0008061346507580719 std(de)=8.23487957277836e-05
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 160, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(160, 80, kernel_size=(6,), stride=(2,), padding=(2,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(80, 1, kernel_size=(6,), stride=(2,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=142001
# R_square_test=0.9999890923500061 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 160]_hc_5_ks_2_ps_2_nconv_0_nblock
#
# de=0.0006217457012490517 std(de)=5.8748621192496815e-05
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))

# %% [markdown]
# #### Plots

# %% [markdown]
# $R^2$

# %%
plt.plot([20,40,80],r,color='black',marker='o')
plt.xlabel('hidden channels',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.show()

# %% [markdown]
# Energy

# %%
plt.errorbar([20,40,80],de,yerr=devde,color='black',marker='o')
plt.xlabel('hidden channels',fontsize=20)
plt.ylabel(r'$\langle \langle|e_{gs}-e_{ML}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Analysis

# %%
ndata=100
ms = []
vs = []
g_acc = []
pseudo_pot = []
v_acc = []
models = []
for i in range(len(hc)):
    data=np.load(data_path[i])
    m=data['density']
    v=data['potential']
    ms.append(m)
    vs.append(v)
    model=torch.load(
        "model_rep/"+models_name[i],
        map_location="cpu",
    )
    models.append(model)
    x = m[:ndata]
    x = torch.tensor(x, dtype=torch.double)
    x.requires_grad_(True)
    f = torch.mean(model(x), dim=-1)
    # print(f.shape)
    f.backward(torch.ones_like(f))
    with torch.no_grad():
        grad = x.grad
        grad = -ls[i] * grad.detach().numpy()
        pseudo_pot = grad
    # print(grad.shape)
    v_acc = np.sqrt(np.average((grad - vs[:ndata]) ** 2, axis=-1)) / np.sqrt(
        np.average((v[:ndata]) ** 2, axis=-1)
    )
    g_acc.append(
        np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
        / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
    )

g_acc = [np.average(g) for g in g_acc]

# %% [markdown]
# #### Plots

# %%
print(g_acc[0].shape)
plt.plot(hc,g_acc)
plt.show()
# Out:
# ()

# %% [markdown]
# ## Case b) U-Net without pooling incresing the kernel size

# %% [markdown]
# #### Data

# %%
ks=[1,3,5,7,9,11]

models_name=[f'2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_1_ks_{k}_ps_2_nconv_0_nblock' for k in ks]

data_path=['data/dataset_2nn/test_unet_periodic_2nn_16_l_5.44_h_100_n.npz']*6



ls=[16]*6

# %% [markdown]
# #### Accuracy analysis

# %%
r,de,devde=test_models_unet(models_name=models_name,data_path=data_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_956468/1815407256.py in <module>
# ----> 1 r,de,devde=test_models_unet(models_name=models_name,data_path=data_path)
#
# ~/dft_for_ising/src/training/utils_analysis.py in test_models_unet(models_name, data_path)
#     104         dl = DataLoader(ds, batch_size=100)
#     105
# --> 106         model = pt.load("model_rep/" + model_name, map_location="cpu")
#     107         model.eval()
#     108         model = model.to(dtype=pt.double)
#
# /opt/anaconda3/envs/dft_env/lib/python3.9/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     592         pickle_load_args['encoding'] = 'utf-8'
#     593
# --> 594     with _open_file_like(f, 'rb') as opened_file:
#     595         if _is_zipfile(opened_file):
#     596             # The zipfile reader is going to advance the current file position.
#
# /opt/anaconda3/envs/dft_env/lib/python3.9/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /opt/anaconda3/envs/dft_env/lib/python3.9/site-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_rep/2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_1_ks_1_ps_2_nconv_0_nblock'

# %% [markdown]
# #### Plots

# %% [markdown]
# $R^2$

# %%
plt.plot(ks,r,color='black',marker='o')
plt.xlabel('kernel size',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.show()

# %% [markdown]
# Energy

# %%
plt.errorbar(ks,de,yerr=devde,color='black',marker='o')
plt.xlabel('hidden channels',fontsize=20)
plt.ylabel(r'$\langle \langle|f_{gs}-f_{ML}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Analysis

# %%
ndata=100
ms = []
vs = []
g_acc = []
pseudo_pot = []
v_acc = []
models = []
for i in range(len(ks)):
    data=np.load(data_path[i])
    m=data['density']
    v=data['potential']
    ms.append(m)
    vs.append(v)
    model=torch.load(
        "model_rep/"+models_name[i],
        map_location="cpu",
    )
    models.append(model)
    x = m[:ndata]
    x = torch.tensor(x, dtype=torch.double)
    x.requires_grad_(True)
    f = torch.mean(model(x), dim=-1)
    # print(f.shape)
    f.backward(torch.ones_like(f))
    with torch.no_grad():
        grad = x.grad
        grad = -ls[i] * grad.detach().numpy()
        pseudo_pot = grad
    # print(grad.shape)
    v_acc = np.sqrt(np.average((grad - vs[:ndata]) ** 2, axis=-1)) / np.sqrt(
        np.average((v[:ndata]) ** 2, axis=-1)
    )
    g_acc.append(
        np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
        / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
    )

g_acc = [np.average(g) for g in g_acc]

# %% [markdown]
# #### Plots

# %%
print(g_acc[0].shape)
plt.plot(ks,g_acc)
plt.show()
# Out:
# ()

# %% [markdown]
# ## Case c) U-Net without pooling size: a study for different kernel sizes

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_1_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock']


ks=[1,3,5,7,9,11]

ls=[16]*len( ks)


data_path=['data/dataset_2nn/test_unet_periodic_2nn_16_l_5.44_h_100_n.npz']*len(ks)

# %% [markdown]
# #### Losses analysis

# %%
for i,model_name in enumerate(models_name):
    plt.figure(figsize=(10,10))
    l_train=torch.load('losses_dft_pytorch/'+model_name+'_loss_train')
    l_valid=torch.load('losses_dft_pytorch/'+model_name+'_loss_valid')

    
    plt.plot(l_train,color='black',label='train')
    plt.plot(l_valid,color='red',linestyle='--',label='valid')
    plt.title(f'kernel_size={ks[i]}',fontsize=20)
    plt.xlabel('epochs',fontsize=20)
    plt.ylabel('Loss',fontsize=20)
    plt.legend(fontsize=20)
    plt.loglog()
    plt.show()

# %% [markdown]
# #### Accuracy

# %%
r,de,devde=test_models_unet(models_name=models_name,data_path=data_path)
# Out:
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(1,), stride=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(1,), stride=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(1,), stride=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=3401
# R_square_test=0.9303698539733887 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_1_ks_1_ps_2_nconv_0_nblock
#
# de=0.01704405142089355 std(de)=0.011814007805344107
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.99997478723526 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.0002542893707701718 std(de)=0.00025757720312498264
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=6.589498515328067e-05 std(de)=6.120556790270633e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9999977350234985 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=9.2326672707861e-05 std(de)=6.095247915871983e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=6.926274204365696e-05 std(de)=6.107124342356411e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9999980330467224 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=7.717732462025701e-05 std(de)=7.041254465456738e-05
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))

# %% [markdown]
# $R^2$

# %%
plt.plot(ks[1:],r[1:],color='black',marker='o')

plt.xlabel('kernel size',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.show()

# %% [markdown]
# Energy

# %%
plt.errorbar(ks,de,yerr=devde,color='black',marker='o')
plt.loglog()
plt.xlabel('kernel size',fontsize=20)
plt.ylabel(r'$\langle \langle|e_{gs}-e_{ML}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Accuracy

# %%
ndata=100
ms = []
vs = []
g_acc = []
pseudo_pot = []
v_acc = []
models = []
for i in range(len(ks)):
    data=np.load(data_path[i])
    m=data['density']
    v=data['potential']
    ms.append(m)
    vs.append(v)
    model=torch.load(
        "model_rep/"+models_name[i],
        map_location="cpu",
    )
    models.append(model)
    x = m[:ndata]
    x = torch.tensor(x, dtype=torch.double)
    x.requires_grad_(True)
    f = torch.mean(model(x), dim=-1)
    # print(f.shape)
    f.backward(torch.ones_like(f))
    with torch.no_grad():
        grad = x.grad
        grad = -ls[i] * grad.detach().numpy()
        pseudo_pot = grad
    # print(grad.shape)
    v_acc = np.sqrt(np.average((grad - vs[:ndata]) ** 2, axis=-1)) / np.sqrt(
        np.average((v[:ndata]) ** 2, axis=-1)
    )
    g_acc.append(
        np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
        / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
    )

g_acc = [np.average(g) for g in g_acc]

# %% [markdown]
# #### Plot

# %%
print(g_acc[0].shape)
plt.plot(ks[1:],g_acc[1:],color='black',marker='o')
plt.xlabel('kernel size',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.show()
# Out:
# ()

# %% [markdown]
# ## Case b) U-Net without pooling incresing the number of convolutional blocks

# %% [markdown]
# #### Imports

# %%
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import test_models_unet

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
            '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_6_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock',
             ]


blocks=np.arange(7)

ls=[16]*len( blocks)


data_path=['data/dataset_2nn/test_unet_periodic_2nn_16_l_5.44_h_100_n.npz']*len(blocks)

# %% [markdown]
# #### Loss Analysis

# %%
for i,model_name in enumerate(models_name):
    plt.figure(figsize=(10,10))
    l_train=torch.load('losses_dft_pytorch/'+model_name+'_loss_train')
    l_valid=torch.load('losses_dft_pytorch/'+model_name+'_loss_valid')

    
    plt.plot(l_train,color='black',label='train')
    plt.plot(l_valid,color='red',linestyle='--',label='valid')
    plt.title(f'blocks={blocks[i+1]}',fontsize=20)
    plt.xlabel('epochs',fontsize=20)
    plt.ylabel('Loss',fontsize=20)
    plt.legend(fontsize=20)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1203131/4050759208.py in <module>
#       7     plt.plot(l_train,color='black',label='train')
#       8     plt.plot(l_valid,color='red',linestyle='--',label='valid')
# ----> 9     plt.title(f'blocks={blocks[i+1]}',fontsize=20)
#      10     plt.xlabel('epochs',fontsize=20)
#      11     plt.ylabel('Loss',fontsize=20)
#
# IndexError: index 7 is out of bounds for axis 0 with size 7

# %% [markdown]
# #### Accuracy

# %%
r,de,devde=test_models_unet(models_name=models_name,data_path=data_path)
# Out:
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00024646942579018157 std(de)=0.00028422869872026923
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00024646942579018157 std(de)=0.00028422869872026923
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9999996423721313 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.00011327565596267749 std(de)=0.0001759627639969945
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999998807907104 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=6.531977657153087e-05 std(de)=7.703780583898704e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9999998807907104 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=6.654941007756781e-05 std(de)=7.574109061359919e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_6): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=80841
# R_square_test=0.9999999403953552 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_6_nconv_0_nblock
#
# de=4.946827132969403e-05 std(de)=3.998981908229647e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9999999403953552 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=5.764712421490567e-05 std(de)=5.447658423771633e-05
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))

# %% [markdown]
# $R^2$

# %%
plt.plot(blocks,r,color='black',marker='o')

plt.xlabel('blocks',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.show()

# %% [markdown]
# Energy

# %%
plt.errorbar(blocks,de,yerr=devde,color='black',marker='o')
plt.semilogy()
plt.xlabel('blocks',fontsize=20)
plt.ylabel(r'$\langle \langle|e_{gs}-e_{ML}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Accuracy

# %%
ndata=100
ms = []
vs = []
g_acc = []
pseudo_pot = []
v_acc = []
models = []
for i in range(len(blocks)):
    data=np.load(data_path[i])
    m=data['density']
    v=data['potential']
    ms.append(m)
    vs.append(v)
    model=torch.load(
        "model_rep/"+models_name[i],
        map_location="cpu",
    )
    models.append(model)
    x = m[:ndata]
    x = torch.tensor(x, dtype=torch.double)
    x.requires_grad_(True)
    f = torch.mean(model(x), dim=-1)
    # print(f.shape)
    f.backward(torch.ones_like(f))
    with torch.no_grad():
        grad = x.grad
        grad = -ls[i] * grad.detach().numpy()
        pseudo_pot = grad
    # print(grad.shape)
    v_acc = np.sqrt(np.average((grad - vs[:ndata]) ** 2, axis=-1)) / np.sqrt(
        np.average((v[:ndata]) ** 2, axis=-1)
    )
    g_acc.append(
        np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
        / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
    )

g_acc = [np.average(g) for g in g_acc]

# %% [markdown]
# #### Plot

# %%
print(g_acc[0].shape)
plt.plot(blocks,g_acc,color='black',marker='o')
plt.xlabel('No. blocks',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.show()
# Out:
# ()

# %% [markdown]
# ## Scalability Performance for different Kernel Size

# %% [markdown]
# #### Data

# %%
ls=[16,24,32,64,96,108,128]
#ls=[16,24,32,48,64]
data_path=[f'data/dataset_2nn/test_unet_periodic_2nn_{l}_l_5.44_h_100_n.npz' for l in ls]
models_name=[#'2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_1_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock']

ks=[3,5,7,9,11]

# %% [markdown]
# #### Accuracy

# %%
rs=[]
des=[]
devdes=[]
for i in range(len(models_name)):
    r,de,devde=test_models_unet(models_name=[models_name[i]]*len(data_path),data_path=data_path)
    rs.append(r)
    des.append(de)
    devdes.append(devde)
# Out:
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.99997478723526 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.000892408567520616 std(de)=0.00011109745753195336
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9998995065689087 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.0016607335380741562 std(de)=0.00014629999327499106
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9998555183410645 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.002058935103766166 std(de)=0.0001549038593143779
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9993399977684021 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.002456868156171092 std(de)=0.00013812859349313412
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.998869776725769 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.0024784721150719865 std(de)=0.00015856459855235667
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9989367723464966 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.0024666194428685038 std(de)=0.00012761622115915674
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9984971880912781 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.002645644983350876 std(de)=0.0001086720441054035
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00024646942579018157 std(de)=2.8422869872026925e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999576210975647 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0010417187851367287 std(de)=0.00010901759588036228
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999289512634277 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0013790079397107751 std(de)=0.00011949583198296
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9995789527893066 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.001890246658333072 std(de)=0.00012342633480893353
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.999203085899353 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0019722808349240577 std(de)=0.00014781966262908923
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9993112683296204 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0018804277997522844 std(de)=0.00011786361618408781
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9990535974502563 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0020296630331186273 std(de)=9.925257760026467e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9999977350234985 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.00031878955521533534 std(de)=2.7894322238961996e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9999746084213257 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.0007831692422195725 std(de)=8.618538165758523e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9999472498893738 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.0011699320479565288 std(de)=0.00010689880018986613
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9996621608734131 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.001630744026344584 std(de)=0.00011944284052445856
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9993616342544556 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.0016601964528067444 std(de)=0.00014484613556092017
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9994658827781677 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.001571112971473574 std(de)=0.0001153602564104532
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9992825984954834 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.00170756642328726 std(de)=9.731712971775339e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.00025036250993365787 std(de)=3.01372041553686e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9999247789382935 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.0014159889879738585 std(de)=0.00011163914010063833
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9998843669891357 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.001766108625782781 std(de)=0.00014401587607625003
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9995133876800537 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.0019792763520050053 std(de)=0.00013825954606949488
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9991140365600586 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.002036428538556477 std(de)=0.00015993812822926638
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9991517066955566 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.00206560494521837 std(de)=0.00013207267395254964
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9989046454429626 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.002150009287060625 std(de)=0.00011359597191015709
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9999980330467224 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.00026737584518579557 std(de)=3.2578656775721494e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9997515678405762 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0022965589138408144 std(de)=0.00019010970229552929
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9996968507766724 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0026835635696692618 std(de)=0.00021036239089367023
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9995400905609131 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0018058972880500063 std(de)=0.0001394881976242725
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9992997050285339 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0017291679405498095 std(de)=0.00014318392214753497
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9992924928665161 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0017957077335653043 std(de)=0.00013081353533724995
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9991293549537659 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0017078855839174434 std(de)=0.0001305146234721647

# %% [markdown]
# $R^2$

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.plot(ls,rs[i],marker='o',label=f'ks={ks[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.legend(fontsize=30)
plt.show()

# %% [markdown]
# Energy

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.errorbar(ls,des[i],yerr=devde,marker='o',label=f'ks={ks[i]}')
plt.legend(fontsize=20)
plt.semilogy()
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle|f_{gs}-f_{ML}|/|f_{gs}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Analysis

# %%
ndata=1000
g_accs=[]
dev_g=[]
for j in range(len(models_name)):
    g_acc = []
    for i in range(len(ls)):
        data=np.load(data_path[i])
        m=data['density']
        v=data['potential']
        model=torch.load(
            "model_rep/"+models_name[j],
            map_location="cpu",
        )
        x = m[:ndata]
        x = torch.tensor(x, dtype=torch.double)
        x.requires_grad_(True)
        f = torch.mean(model(x), dim=-1)
        # print(f.shape)
        f.backward(torch.ones_like(f))
        with torch.no_grad():
            grad = x.grad
            grad = -ls[i] * grad.detach().numpy()
            pseudo_pot = grad
        # print(grad.shape)
        g_acc.append(
            np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
            / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
        )

    dev_g.append([np.std(g)/np.sqrt(g.shape[0]) for g in g_acc])
    g_acc = [np.average(g) for g in g_acc]
    g_accs.append(g_acc)

# %% [markdown]
# #### Plots

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.errorbar(ls,g_accs[i],yerr=dev_g[i],marker='o',label=f'ks={ks[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ### Gradient Descent Accuracy

# %% [markdown]
# #### Imports

# %%
import os
import time
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import dataloader, nuv_representability_check,mean_field_functional_1nn

# %% [markdown]
# #### Data

# %%
ks=[1,3,5,7,9,11]
n_sample=len(ks)
h_max=[5.44]*n_sample
ls=[128]*n_sample
n_instances=[100]*n_sample
epochs = [1900]*n_sample 
# model settings
name_session=[f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_2_layers_40_hc_{ks[i]}_ks_1_ps' for i in range(n_sample) ]

early_stopping=False
variational_lr=False
loglr=1

min_density=[]
gs_density=[]
min_energy=[]
gs_energy=[]
hs=[]

for i in range(n_sample):
    hs.append(np.load(f'data/dataset_2nn/test_unet_periodic_2nn_{ls[i]}_l_{h_max[i]}_h_100_n.npz')['potential'][0:n_instances[i]])
    min_eng_t,gs_eng_t=dataloader('energy',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    min_n_t,gs_n_t=dataloader('density',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    
    min_eng_t=np.asarray(min_eng_t)
    gs_eng_t=np.asarray(gs_eng_t)
    min_n_t=np.asarray(min_n_t)
    gs_n_t=np.asarray(gs_n_t)
    
            #if min_eng_t.shape[0]==min_eng.shape[-1]:
    min_energy.append(min_eng_t)
    gs_energy.append(gs_eng_t)
    min_density.append(min_n_t)
    gs_density.append(gs_n_t)
    
min_energy=np.asarray(min_energy)
gs_energy=np.asarray(gs_energy)
min_density=np.asarray(min_density)
gs_density=np.asarray(gs_density)

# %% [markdown]
# #### Accuracy for different ks

# %% [markdown]
# Magnetization

# %%
dz=(np.average(np.abs(gs_density-min_density),axis=-1))/np.average(np.abs(gs_density),axis=-1)

fig=plt.figure(figsize=(5,5))
plt.plot(ks,np.average(dz,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'kernel size',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta z|}{|z|} \rangle$',fontsize=30)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.semilogy()
plt.show()

# %% [markdown]
# Energy

# %%
de=np.abs(gs_energy-min_energy)/np.abs(gs_energy)

fig=plt.figure(figsize=(5,5))
plt.plot(ks,np.average(de,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'kernel size',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta e|}{|e|} \rangle$',fontsize=30)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.semilogy()
plt.show()

# %% [markdown]
# ## Scalability analysis at different Depth of the Neural Network

# %% [markdown]
# #### Imports

# %%
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import test_models_unet

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock',
             #'2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_6_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock',
             ]


blocks=[1,2,3,4,5,7]
ls=[16,24,32,64,96,128]
#ls=[16,24,32,48,64]

data_path=[f'data/dataset_2nn/test_unet_periodic_2nn_{l}_l_5.44_h_100_n.npz' for l in ls]

# %% [markdown]
# #### Accuracy

# %%
rs=[]
des=[]
devdes=[]
for i in range(len(models_name)):
    r,de,devde=test_models_unet(models_name=[models_name[i]]*len(data_path),data_path=data_path)
    rs.append(r)
    des.append(de)
    devdes.append(devde)
# Out:
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9997571706771851 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.003132776573148441 std(de)=0.00032542826803052524
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9997673034667969 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.0023934105640401647 std(de)=0.00022668809946255208
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9996859431266785 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.002848301360585416 std(de)=0.0002524504930351196
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9989383220672607 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.0029628641951886087 std(de)=0.00019658557211856147
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9984142780303955 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.0027810963919413702 std(de)=0.0002133417331035276
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9978039264678955 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.0031028375470178423 std(de)=0.00015142189040505177
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00024646942579018157 std(de)=2.8422869872026925e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999576210975647 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0010417187851367287 std(de)=0.00010901759588036228
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999289512634277 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0013790079397107751 std(de)=0.00011949583198296
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9995789527893066 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.001890246658333072 std(de)=0.00012342633480893353
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.999203085899353 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0019722808349240577 std(de)=0.00014781966262908923
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9990535974502563 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0020296630331186273 std(de)=9.925257760026467e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9999996423721313 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.00011327565596267749 std(de)=1.759627639969945e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9999725222587585 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.0008559363289493467 std(de)=8.413403094415191e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9999478459358215 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.0011642369631306732 std(de)=0.00010779240970031255
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9996428489685059 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.0017018048489491034 std(de)=0.00011967044514986712
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9993196129798889 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.001765491063913658 std(de)=0.0001430143512957249
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9992049932479858 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.0018248593227813178 std(de)=9.706640716635727e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999998807907104 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=6.531977657153087e-05 std(de)=7.703780583898704e-06
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999713897705078 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0008675965741032392 std(de)=8.698719203456123e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999428391456604 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.001231805076828726 std(de)=0.0001118383472933021
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9996334910392761 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017347556874996626 std(de)=0.00012046487108028628
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999306857585907 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017819450537597415 std(de)=0.00014509773975661454
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9991859793663025 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0018481067773635528 std(de)=9.820431674779798e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9999998807907104 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=6.654941007756781e-05 std(de)=7.574109061359919e-06
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9999697208404541 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.0008911556892714684 std(de)=9.002618646362088e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9999375939369202 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.0012891285993389635 std(de)=0.000116223038820307
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9996160268783569 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.0017828096355916349 std(de)=0.00012249360203202964
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9992769360542297 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.0018394401884176692 std(de)=0.000145811051513051
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9991573095321655 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.0018878570716413271 std(de)=9.87377740732354e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9999999403953552 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=5.764712421490567e-05 std(de)=5.4476584237716335e-06
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9999721050262451 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.0008472789665210197 std(de)=8.816234679094099e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9999426603317261 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.0012270870627774898 std(de)=0.00011374731430368931
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9996366500854492 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.001716582257722723 std(de)=0.0001223063077731949
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9992997646331787 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.0017907698966848728 std(de)=0.00014607932479192718
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9991840124130249 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.001846873961903375 std(de)=9.93963067421908e-05

# %% [markdown]
# $R^2$

# %%
plt.figure(figsize=(10,10))

for i in range(len(models_name)):
    plt.plot(ls,rs[i],marker='o',label=f'blocks={blocks[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.legend(fontsize=30)
plt.show()

# %% [markdown]
# Energy

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.errorbar(ls,des[i],yerr=devde,marker='o',label=f'blocks={blocks[i]}')
plt.legend(fontsize=20)
plt.semilogy()
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle|f_{gs}-f_{ML}|/|f_{gs}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Descent Accuracy

# %%
ndata=100
g_accs=[]
dev_g=[]
for j in range(len(models_name)):
    g_acc = []
    for i in range(len(ls)):
        data=np.load(data_path[i])
        m=data['density']
        v=data['potential']
        model=torch.load(
            "model_rep/"+models_name[j],
            map_location="cpu",
        )
        x = m[:ndata]
        x = torch.tensor(x, dtype=torch.double)
        x.requires_grad_(True)
        f = torch.mean(model(x), dim=-1)
        # print(f.shape)
        f.backward(torch.ones_like(f))
        with torch.no_grad():
            grad = x.grad
            grad = -ls[i] * grad.detach().numpy()
            pseudo_pot = grad
        # print(grad.shape)
        g_acc.append(
            np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
            / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
        )

    dev_g.append([np.std(g)/np.sqrt(g.shape[0]) for g in g_acc])
    g_acc = [np.average(g) for g in g_acc]
    g_accs.append(g_acc)

# %% [markdown]
# #### Plots

# %%
plt.figure(figsize=(10,10))
for i in range(1,len(models_name)):
    plt.errorbar(ls,g_accs[i],yerr=dev_g[i],marker='o',label=f'blocks={blocks[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.loglog()
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ### Gradient Descent Accuracy

# %% [markdown]
# #### Imports

# %%
import os
import time
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import dataloader, nuv_representability_check,mean_field_functional_1nn

# %% [markdown]
# #### Data

# %%
blocks=[2,3,4,5,7]

n_sample=5
h_max=[5.44]*n_sample
ls=[16]*n_sample
n_instances=[100]*n_sample
epochs = [1900]*n_sample 
# model settings
name_session=[f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_2_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_3_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_4_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_5_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_6_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_7_layers_40_hc_5_ks_1_ps' ]

early_stopping=False
variational_lr=False
loglr=1

min_density=[]
gs_density=[]
min_energy=[]
gs_energy=[]
hs=[]

for i in range(n_sample):
    hs.append(np.load(f'data/dataset_2nn/test_unet_periodic_2nn_{ls[i]}_l_{h_max[i]}_h_100_n.npz')['potential'][0:n_instances[i]])
    min_eng_t,gs_eng_t=dataloader('energy',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    min_n_t,gs_n_t=dataloader('density',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    
    min_eng_t=np.asarray(min_eng_t)
    gs_eng_t=np.asarray(gs_eng_t)
    min_n_t=np.asarray(min_n_t)
    gs_n_t=np.asarray(gs_n_t)
    
            #if min_eng_t.shape[0]==min_eng.shape[-1]:
    min_energy.append(min_eng_t)
    gs_energy.append(gs_eng_t)
    min_density.append(min_n_t)
    gs_density.append(gs_n_t)
    
min_energy=np.asarray(min_energy)
gs_energy=np.asarray(gs_energy)
min_density=np.asarray(min_density)
gs_density=np.asarray(gs_density)

# %% [markdown]
# #### Accuracy for different dept

# %% [markdown]
# Magnetization

# %%
dz=(np.average(np.abs(gs_density-min_density),axis=-1))/np.average(np.abs(gs_density),axis=-1)

fig=plt.figure(figsize=(5,5))
plt.plot(blocks,np.average(dz,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'No. Blocks',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta z|}{|z|} \rangle$',fontsize=30)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.show()

# %% [markdown]
# Energy

# %%
de=np.abs(gs_energy-min_energy)/np.abs(gs_energy)

fig=plt.figure(figsize=(5,5))
plt.plot(blocks,np.average(de,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'No. Blocks',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta e|}{|e|} \rangle$',fontsize=30)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.show()

# %% [markdown]
# ## Hidden channel case

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
            '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock',
            '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock',
             ]
hc=[40,80,120]
ls=[16,24,32,64,96,108,128,136]
data_path=[f'data/dataset_2nn/test_unet_periodic_2nn_{l}_l_5.44_h_100_n.npz' for l in ls]

# %% [markdown]
# #### Accuracy

# %%
rs=[]
des=[]
devdes=[]
for i in range(len(models_name)):
    r,de,devde=test_models_unet(models_name=[models_name[i]]*len(data_path),data_path=data_path)
    rs.append(r)
    des.append(de)
    devdes.append(devde)
# Out:
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00024646942579018157 std(de)=2.8422869872026925e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999576210975647 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0010417187851367287 std(de)=0.00010901759588036228
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999289512634277 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0013790079397107751 std(de)=0.00011949583198296
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9995789527893066 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.001890246658333072 std(de)=0.00012342633480893353
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.999203085899353 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0019722808349240577 std(de)=0.00014781966262908923
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9993112683296204 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0018804277997522844 std(de)=0.00011786361618408781
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9990535974502563 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0020296630331186273 std(de)=9.925257760026467e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9991507530212402 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0019697034766959155 std(de)=0.00011286405904298388
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.999998927116394 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.000211914853362964 std(de)=2.5831763798183572e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9999566078186035 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0010464846726957735 std(de)=0.00011270476084529905
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9999258518218994 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0014228764009088684 std(de)=0.00012427241422872674
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.999572217464447 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0019036605617902497 std(de)=0.000127014479259197
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9992141127586365 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0019534593254284696 std(de)=0.00014755764193361226
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.999311625957489 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0018866789170328925 std(de)=0.00011801638925865038
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9990586638450623 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.002023429639473594 std(de)=0.00010011550767023892
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9991545081138611 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.001965384334940576 std(de)=0.00011258425295050817
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9999989867210388 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00019932613460115354 std(de)=2.2024845818598833e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9999583959579468 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0010278611694075675 std(de)=0.0001094754456451796
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9999279379844666 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0013711530465351613 std(de)=0.00012506881866883456
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9995790123939514 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0018849893325365537 std(de)=0.00012573205491124047
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9992226362228394 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.001942616000987235 std(de)=0.00014706432558830957
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9993316531181335 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.001853923591771265 std(de)=0.00011696499864074036
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9990779757499695 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.001998748345339324 std(de)=9.98919005711723e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9991785883903503 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0019283446380858613 std(de)=0.00011225637880855533

# %% [markdown]
# $R^2$

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.plot(ls,rs[i],marker='o',label=f'hc={hc[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.legend(fontsize=30)
plt.show()

# %% [markdown]
# Energy

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.errorbar(ls,des[i],yerr=devde,marker='o',label=f'hc={hc[i]}')
plt.legend(fontsize=20)
plt.semilogy()
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle|f_{gs}-f_{ML}|/|f_{gs}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Descent Analysis

# %%
ndata=1000
g_accs=[]
dev_g=[]
for j in range(len(models_name)):
    g_acc = []
    for i in range(len(ls)):
        data=np.load(data_path[i])
        m=data['density']
        v=data['potential']
        model=torch.load(
            "model_rep/"+models_name[j],
            map_location="cpu",
        )
        x = m[:ndata]
        x = torch.tensor(x, dtype=torch.double)
        x.requires_grad_(True)
        f = torch.mean(model(x), dim=-1)
        # print(f.shape)
        f.backward(torch.ones_like(f))
        with torch.no_grad():
            grad = x.grad
            grad = -ls[i] * grad.detach().numpy()
            pseudo_pot = grad
        # print(grad.shape)
        g_acc.append(
            np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
            / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
        )

    dev_g.append([np.std(g)/np.sqrt(g.shape[0]) for g in g_acc])
    g_acc = [np.average(g) for g in g_acc]
    g_accs.append(g_acc)

# %% [markdown]
# #### Plots

# %%
plt.figure(figsize=(10,10))
for i in range(0,len(models_name)):
    plt.errorbar(ls,g_accs[i],yerr=dev_g[i],marker='o',label=f'hc={hc[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.loglog()
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## Analysis for different sizes of the Dataset

# %% [markdown]
# #### Imports

# %%
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import test_models_unet

# %% [markdown]
# ##### Data

# %%
n_dataset=['5k','10k','15k','30k','150k']
models_name=['2nn_ising/h_5.44_'+n_data+'_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock' for n_data in n_dataset]
ls=[16,24,32,64,96,108,128,136]
data_path=[f'data/dataset_2nn/test_unet_periodic_2nn_{l}_l_5.44_h_100_n.npz' for l in ls]

# %% [markdown]
# #### Accuracy

# %%
rs=[]
des=[]
devdes=[]
for i in range(len(models_name)):
    r,de,devde=test_models_unet(models_name=[models_name[i]]*len(data_path),data_path=data_path)
    rs.append(r)
    des.append(de)
    devdes.append(devde)
# Out:
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999995827674866 for 2nn_ising/h_5.44_5k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.00012403788589678653 std(de)=1.4396899808386574e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999726414680481 for 2nn_ising/h_5.44_5k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0008444619994851096 std(de)=8.615680338792383e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999943733215332 for 2nn_ising/h_5.44_5k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0012115728954506353 std(de)=0.00011218413103636317
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9996418952941895 for 2nn_ising/h_5.44_5k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.001705478915039004 std(de)=0.00012073213805965288
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9993072152137756 for 2nn_ising/h_5.44_5k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017766597141865299 std(de)=0.00014575995325532033
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9994162321090698 for 2nn_ising/h_5.44_5k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0016909675639502594 std(de)=0.00011328832692569573
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9992130398750305 for 2nn_ising/h_5.44_5k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0018084011324114057 std(de)=9.879426406803457e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999283492565155 for 2nn_ising/h_5.44_5k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017712285713616918 std(de)=0.00010955287559984478
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999998211860657 for 2nn_ising/h_5.44_10k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=7.791498672062913e-05 std(de)=1.045021711138841e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999968945980072 for 2nn_ising/h_5.44_10k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0009112823641947278 std(de)=8.987222239512042e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999388456344604 for 2nn_ising/h_5.44_10k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0012823494160864302 std(de)=0.00011394170733782831
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9996151924133301 for 2nn_ising/h_5.44_10k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017887464504713097 std(de)=0.00012138848075413305
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999278724193573 for 2nn_ising/h_5.44_10k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0018235322453854744 std(de)=0.0001471218054440531
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9993680119514465 for 2nn_ising/h_5.44_10k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017818221297736692 std(de)=0.00011502477216496394
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9991515874862671 for 2nn_ising/h_5.44_10k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.001893319183615977 std(de)=9.901221220507016e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9992321133613586 for 2nn_ising/h_5.44_10k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0018516608167648823 std(de)=0.00011013565519430201
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999998807907104 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=6.531977657153087e-05 std(de)=7.703780583898704e-06
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999713897705078 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0008675965741032392 std(de)=8.698719203456123e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999428391456604 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.001231805076828726 std(de)=0.0001118383472933021
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9996334910392761 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017347556874996626 std(de)=0.00012046487108028628
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999306857585907 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017819450537597415 std(de)=0.00014509773975661454
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9994025826454163 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017182262471257417 std(de)=0.00011420816769358988
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9991859793663025 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0018481067773635528 std(de)=9.820431674779798e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9992632865905762 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0018033911843240676 std(de)=0.00010915711323426291
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999999403953552 for 2nn_ising/h_5.44_30k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=5.7250905458498594e-05 std(de)=6.391973865921372e-06
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999750256538391 for 2nn_ising/h_5.44_30k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0008000961667731253 std(de)=8.234149318022701e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999467134475708 for 2nn_ising/h_5.44_30k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0011828140423670729 std(de)=0.00010843391119751047
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999646782875061 for 2nn_ising/h_5.44_30k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0016935104654097585 std(de)=0.0001193203590209647
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9993321895599365 for 2nn_ising/h_5.44_30k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017249717308030947 std(de)=0.00014505922528531458
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9994226694107056 for 2nn_ising/h_5.44_30k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.001679111041173182 std(de)=0.00011316804234283922
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9992311596870422 for 2nn_ising/h_5.44_30k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017822904862676253 std(de)=9.745704213700879e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9992985129356384 for 2nn_ising/h_5.44_30k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.001750760664773084 std(de)=0.00010788902224216821
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999999403953552 for 2nn_ising/h_5.44_150k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=4.321455918472203e-05 std(de)=4.115399387708499e-06
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999977707862854 for 2nn_ising/h_5.44_150k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0007418644800236948 std(de)=7.978712906355894e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999536275863647 for 2nn_ising/h_5.44_150k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0010838549265778043 std(de)=0.00010452241741687522
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999671459197998 for 2nn_ising/h_5.44_150k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0016169103557165311 std(de)=0.00011732597159717861
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9993689656257629 for 2nn_ising/h_5.44_150k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.001663134457810374 std(de)=0.00014231535075695937
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9994542002677917 for 2nn_ising/h_5.44_150k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.001610497285270196 std(de)=0.00011250367757914262
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9992777705192566 for 2nn_ising/h_5.44_150k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0017131005964137302 std(de)=9.677431752803829e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9993451237678528 for 2nn_ising/h_5.44_150k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0016738699725368778 std(de)=0.00010691795167199915

# %% [markdown]
# $R^2$

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.plot(ls,rs[i],marker='o',label=f'No data={n_dataset[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.legend(fontsize=30)
plt.show()

# %% [markdown]
# Energy

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.errorbar(ls,des[i],yerr=devde,marker='o',label=f'No data={n_dataset[i]}')
plt.legend(fontsize=20)
plt.semilogy()
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle|f_{gs}-f_{ML}|/|f_{gs}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Accuracy

# %%
ndata=1000
g_accs=[]
dev_g=[]
for j in range(len(models_name)):
    g_acc = []
    for i in range(len(ls)):
        data=np.load(data_path[i])
        m=data['density']
        v=data['potential']
        model=torch.load(
            "model_rep/"+models_name[j],
            map_location="cpu",
        )
        x = m[:ndata]
        x = torch.tensor(x, dtype=torch.double)
        x.requires_grad_(True)
        f = torch.mean(model(x), dim=-1)
        # print(f.shape)
        f.backward(torch.ones_like(f))
        with torch.no_grad():
            grad = x.grad
            grad = -ls[i] * grad.detach().numpy()
            pseudo_pot = grad
        # print(grad.shape)
        g_acc.append(
            np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
            / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
        )

    dev_g.append([np.std(g)/np.sqrt(g.shape[0]) for g in g_acc])
    g_acc = [np.average(g) for g in g_acc]
    g_accs.append(g_acc)

# %% [markdown]
# #### Plots

# %%
plt.figure(figsize=(10,10))
for i in range(1,len(models_name)):
    plt.errorbar(ls,g_accs[i],yerr=dev_g[i],marker='o',label=f'No data={n_dataset[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.loglog()
plt.legend(fontsize=20)
plt.show()

# %%
n_dataset=['5k','10k','15k','30k','150k']
n_sample=len(n_dataset)
h_max=[5.44]*n_sample
ls=[128]*n_sample
ks=[5]*n_sample
n_instances=[100]*n_sample
epochs = [1900]*n_sample 
# model settings
name_session=[f'h_{h_max[0]}_{n_dataset[i]}_augmentation_2nn_model_unet_{ls[0]}_size_4_layers_40_hc_{ks[0]}_ks_1_ps' for i in range(n_sample) ]

early_stopping=False
variational_lr=False
loglr=1

min_density=[]
gs_density=[]
min_energy=[]
gs_energy=[]
hs=[]

for i in range(n_sample):
    hs.append(np.load(f'data/dataset_2nn/test_unet_periodic_2nn_{ls[i]}_l_{h_max[i]}_h_100_n.npz')['potential'][0:n_instances[i]])
    min_eng_t,gs_eng_t=dataloader('energy',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    min_n_t,gs_n_t=dataloader('density',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    
    min_eng_t=np.asarray(min_eng_t)
    gs_eng_t=np.asarray(gs_eng_t)
    min_n_t=np.asarray(min_n_t)
    gs_n_t=np.asarray(gs_n_t)
    
            #if min_eng_t.shape[0]==min_eng.shape[-1]:
    min_energy.append(min_eng_t)
    gs_energy.append(gs_eng_t)
    min_density.append(min_n_t)
    gs_density.append(gs_n_t)
    
min_energy=np.asarray(min_energy)
gs_energy=np.asarray(gs_energy)
min_density=np.asarray(min_density)
gs_density=np.asarray(gs_density)

# %%
dz=(np.average(np.abs(gs_density-min_density),axis=-1))/np.average(np.abs(gs_density),axis=-1)

fig=plt.figure(figsize=(5,5))
plt.plot(np.average(dz,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'No instances',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta z|}{|z|} \rangle$',fontsize=30)
plt.xticks(np.arange(len(n_dataset)),n_dataset)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.show()

# %%
de=np.abs(gs_energy-min_energy)/np.abs(gs_energy)

fig=plt.figure(figsize=(5,5))
plt.plot(np.average(de,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'No. Instances',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta e|}{|e|} \rangle$',fontsize=30)
plt.xticks(np.arange(len(n_dataset)),n_dataset)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.show()
