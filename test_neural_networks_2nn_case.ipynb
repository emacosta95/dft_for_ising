# %% [markdown]
# # Accuracy optimization of the DFT U-net

# %% [markdown]
# We demonstrate that a pure scalability can be reached for both the 1nn and 2nn system. However we can reach accuracies that can be considered low (rel err$=10^{-3}$). For this reason we wonder if we can force the CNN to outperform by increasing the learning capacity in both hidden channels, kernel size and convolutional blocks (without pooling).
#
# We consider the 2nn case in the critical point and two datasets with $1.5 \cdot 10^3$ and $1.5 \cdot 10^4$ sample.

# %% [markdown]
# #### Imports

# %%
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import test_models_unet

# %% [markdown]
# ## Case a) U-Net with pooling incresing the number of Hidden channels

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_5_ks_2_ps_2_nconv_0_nblock','2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 80]_hc_5_ks_2_ps_2_nconv_0_nblock','2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 160]_hc_5_ks_2_ps_2_nconv_0_nblock']

data_path=['data/dataset_2nn/test_unet_periodic_2nn_16_l_5.44_h_100_n.npz']*3

hc=[20,40,80]

ls=[128]*3

# %% [markdown]
# #### Accuracy analysis

# %%
r,de,devde=test_models_unet(models_name=models_name,data_path=data_path)
# Out:
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 20, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(20, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(40, 20, kernel_size=(6,), stride=(2,), padding=(2,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(20, 1, kernel_size=(6,), stride=(2,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=9101
# R_square_test=0.9998987913131714 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_5_ks_2_ps_2_nconv_0_nblock
#
# de=0.0005739430305899525 std(de)=0.0004567226154146769
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(80, 40, kernel_size=(6,), stride=(2,), padding=(2,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(40, 1, kernel_size=(6,), stride=(2,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=35801
# R_square_test=0.9999830722808838 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 80]_hc_5_ks_2_ps_2_nconv_0_nblock
#
# de=0.000233913794665472 std(de)=0.0001881146898925404
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 160, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(160, 80, kernel_size=(6,), stride=(2,), padding=(2,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(80, 1, kernel_size=(6,), stride=(2,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=142001
# R_square_test=0.9999890923500061 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 160]_hc_5_ks_2_ps_2_nconv_0_nblock
#
# de=0.00018397923931177295 std(de)=0.00016253674151184196

# %% [markdown]
# #### Plots

# %% [markdown]
# $R^2$

# %%
plt.plot([20,40,80],r,color='black',marker='o')
plt.xlabel('hidden channels',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.show()

# %% [markdown]
# Energy

# %%
plt.errorbar([20,40,80],de,yerr=devde,color='black',marker='o')
plt.xlabel('hidden channels',fontsize=20)
plt.ylabel(r'$\langle \langle|e_{gs}-e_{ML}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Analysis

# %%
ndata=100
ms = []
vs = []
g_acc = []
pseudo_pot = []
v_acc = []
models = []
for i in range(len(hc)):
    data=np.load(data_path[i])
    m=data['density']
    v=data['potential']
    ms.append(m)
    vs.append(v)
    model=torch.load(
        "model_rep/"+models_name[i],
        map_location="cpu",
    )
    models.append(model)
    x = m[:ndata]
    x = torch.tensor(x, dtype=torch.double)
    x.requires_grad_(True)
    f = torch.mean(model(x), dim=-1)
    # print(f.shape)
    f.backward(torch.ones_like(f))
    with torch.no_grad():
        grad = x.grad
        grad = -ls[i] * grad.detach().numpy()
        pseudo_pot = grad
    # print(grad.shape)
    v_acc = np.sqrt(np.average((grad - vs[:ndata]) ** 2, axis=-1)) / np.sqrt(
        np.average((v[:ndata]) ** 2, axis=-1)
    )
    g_acc.append(
        np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
        / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
    )

g_acc = [np.average(g) for g in g_acc]

# %% [markdown]
# #### Plots

# %%
print(g_acc[0].shape)
plt.plot(hc,g_acc)
plt.show()
# Out:
# ()

# %% [markdown]
# ## Case b) U-Net without pooling incresing the kernel size

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_1_ks_2_ps_2_nconv_0_nblock','2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_3_ks_2_ps_2_nconv_0_nblock','2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_5_ks_2_ps_2_nconv_0_nblock',
'2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_7_ks_2_ps_2_nconv_0_nblock']

data_path=['data/dataset_2nn/test_unet_periodic_2nn_16_l_5.44_h_100_n.npz']*4

ks=[1,3,5,7]

ls=[16]*4

# %% [markdown]
# #### Accuracy analysis

# %%
r,de,devde=test_models_unet(models_name=models_name,data_path=data_path)
# Out:
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 20, kernel_size=(1,), stride=(1,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(20, 40, kernel_size=(1,), stride=(1,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(40, 20, kernel_size=(2,), stride=(2,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(20, 1, kernel_size=(2,), stride=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=2541
# R_square_test=0.9896542429924011 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_1_ks_2_ps_2_nconv_0_nblock
#
# de=0.00631862403348602 std(de)=0.00463064602942907
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 20, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(20, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(40, 20, kernel_size=(4,), stride=(2,), padding=(1,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(20, 1, kernel_size=(4,), stride=(2,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=5821
# R_square_test=0.9999091029167175 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_3_ks_2_ps_2_nconv_0_nblock
#
# de=0.0005726606024248741 std(de)=0.00043896716885211243
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 20, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(20, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(40, 20, kernel_size=(6,), stride=(2,), padding=(2,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(20, 1, kernel_size=(6,), stride=(2,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=9101
# R_square_test=0.9998987913131714 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_5_ks_2_ps_2_nconv_0_nblock
#
# de=0.0005739430305899525 std(de)=0.0004567226154146769
# REDENT(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 20, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#       (pooling 1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#     (1): Sequential(
#       (conv2): Conv1d(20, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#       (pooling 2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): ConvTranspose1d(40, 20, kernel_size=(8,), stride=(2,), padding=(3,))
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): ConvTranspose1d(20, 1, kernel_size=(8,), stride=(2,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=12381
# R_square_test=0.9999033808708191 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[20, 40]_hc_7_ks_2_ps_2_nconv_0_nblock
#
# de=0.0006313440112459006 std(de)=0.0003806076724551388
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))

# %% [markdown]
# #### Plots

# %% [markdown]
# $R^2$

# %%
plt.plot(ks,r,color='black',marker='o')
plt.xlabel('kernel size',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.show()

# %% [markdown]
# Energy

# %%
plt.errorbar(ks,de,yerr=devde,color='black',marker='o')
plt.xlabel('hidden channels',fontsize=20)
plt.ylabel(r'$\langle \langle|e_{gs}-e_{ML}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Analysis

# %%
ndata=100
ms = []
vs = []
g_acc = []
pseudo_pot = []
v_acc = []
models = []
for i in range(len(ks)):
    data=np.load(data_path[i])
    m=data['density']
    v=data['potential']
    ms.append(m)
    vs.append(v)
    model=torch.load(
        "model_rep/"+models_name[i],
        map_location="cpu",
    )
    models.append(model)
    x = m[:ndata]
    x = torch.tensor(x, dtype=torch.double)
    x.requires_grad_(True)
    f = torch.mean(model(x), dim=-1)
    # print(f.shape)
    f.backward(torch.ones_like(f))
    with torch.no_grad():
        grad = x.grad
        grad = -ls[i] * grad.detach().numpy()
        pseudo_pot = grad
    # print(grad.shape)
    v_acc = np.sqrt(np.average((grad - vs[:ndata]) ** 2, axis=-1)) / np.sqrt(
        np.average((v[:ndata]) ** 2, axis=-1)
    )
    g_acc.append(
        np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
        / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
    )

g_acc = [np.average(g) for g in g_acc]

# %% [markdown]
# #### Plots

# %%
print(g_acc[0].shape)
plt.plot(ks,g_acc)
plt.show()
# Out:
# ()

# %% [markdown]
# ## Case c) U-Net without pooling size: a study for different kernel sizes

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_1_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock']


ks=[1,3,5,7,9,11]

ls=[16]*len( ks)


data_path=['data/dataset_2nn/test_unet_periodic_2nn_16_l_5.44_h_100_n.npz']*len(ks)

# %% [markdown]
# #### Losses analysis

# %%
for i,model_name in enumerate(models_name):
    plt.figure(figsize=(10,10))
    l_train=torch.load('losses_dft_pytorch/'+model_name+'_loss_train')
    l_valid=torch.load('losses_dft_pytorch/'+model_name+'_loss_valid')

    
    plt.plot(l_train,color='black',label='train')
    plt.plot(l_valid,color='red',linestyle='--',label='valid')
    plt.title(f'kernel_size={ks[i]}',fontsize=20)
    plt.xlabel('epochs',fontsize=20)
    plt.ylabel('Loss',fontsize=20)
    plt.legend(fontsize=20)
    plt.loglog()
    plt.show()

# %% [markdown]
# #### Accuracy

# %%
r,de,devde=test_models_unet(models_name=models_name,data_path=data_path)
# Out:
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(1,), stride=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(1,), stride=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(1,), stride=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=3401
# R_square_test=0.9303698539733887 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_1_ks_1_ps_2_nconv_0_nblock
#
# de=0.01704405142089355 std(de)=0.011814007805344107
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.99997478723526 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.0002542893707701718 std(de)=0.00025757720312498264
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=6.589498515328067e-05 std(de)=6.120556790270633e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9999977350234985 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=9.2326672707861e-05 std(de)=6.095247915871983e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9999974966049194 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=8.890216528765673e-05 std(de)=7.065102629857717e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9999970197677612 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=9.281166693790391e-05 std(de)=8.781098136459063e-05
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))

# %% [markdown]
# $R^2$

# %%
plt.plot(ks[1:],r[1:],color='black',marker='o')

plt.xlabel('kernel size',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.show()

# %% [markdown]
# Energy

# %%
plt.errorbar(ks,de,yerr=devde,color='black',marker='o')
plt.loglog()
plt.xlabel('kernel size',fontsize=20)
plt.ylabel(r'$\langle \langle|e_{gs}-e_{ML}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Accuracy

# %%
ndata=100
ms = []
vs = []
g_acc = []
pseudo_pot = []
v_acc = []
models = []
for i in range(len(ks)):
    data=np.load(data_path[i])
    m=data['density']
    v=data['potential']
    ms.append(m)
    vs.append(v)
    model=torch.load(
        "model_rep/"+models_name[i],
        map_location="cpu",
    )
    models.append(model)
    x = m[:ndata]
    x = torch.tensor(x, dtype=torch.double)
    x.requires_grad_(True)
    f = torch.mean(model(x), dim=-1)
    # print(f.shape)
    f.backward(torch.ones_like(f))
    with torch.no_grad():
        grad = x.grad
        grad = -ls[i] * grad.detach().numpy()
        pseudo_pot = grad
    # print(grad.shape)
    v_acc = np.sqrt(np.average((grad - vs[:ndata]) ** 2, axis=-1)) / np.sqrt(
        np.average((v[:ndata]) ** 2, axis=-1)
    )
    g_acc.append(
        np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
        / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
    )

g_acc = [np.average(g) for g in g_acc]

# %% [markdown]
# #### Plot

# %%
print(g_acc[0].shape)
plt.plot(ks[1:],g_acc[1:],color='black',marker='o')
plt.xlabel('kernel size',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.show()
# Out:
# ()

# %% [markdown]
# ## Case b) U-Net without pooling incresing the number of convolutional blocks

# %% [markdown]
# #### Imports

# %%
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import test_models_unet

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
            '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_6_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock',
             ]


blocks=np.arange(7)

ls=[16]*len( blocks)


data_path=['data/dataset_2nn/test_unet_periodic_2nn_16_l_5.44_h_100_n.npz']*len(blocks)

# %% [markdown]
# #### Loss Analysis

# %%
for i,model_name in enumerate(models_name):
    plt.figure(figsize=(10,10))
    l_train=torch.load('losses_dft_pytorch/'+model_name+'_loss_train')
    l_valid=torch.load('losses_dft_pytorch/'+model_name+'_loss_valid')

    
    plt.plot(l_train,color='black',label='train')
    plt.plot(l_valid,color='red',linestyle='--',label='valid')
    plt.title(f'blocks={blocks[i+1]}',fontsize=20)
    plt.xlabel('epochs',fontsize=20)
    plt.ylabel('Loss',fontsize=20)
    plt.legend(fontsize=20)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_701597/4050759208.py in <module>
#       7     plt.plot(l_train,color='black',label='train')
#       8     plt.plot(l_valid,color='red',linestyle='--',label='valid')
# ----> 9     plt.title(f'blocks={blocks[i+1]}',fontsize=20)
#      10     plt.xlabel('epochs',fontsize=20)
#      11     plt.ylabel('Loss',fontsize=20)
#
# IndexError: index 7 is out of bounds for axis 0 with size 7

# %% [markdown]
# #### Accuracy

# %%
r,de,devde=test_models_unet(models_name=models_name,data_path=data_path)
# Out:
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=6.589498515328067e-05 std(de)=6.120556790270633e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=6.589498515328067e-05 std(de)=6.120556790270633e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9999996423721313 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=2.809142875113842e-05 std(de)=2.8220093530883197e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=87401
# R_square_test=0.9999989867210388 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_9_ks_1_ps_4_nconv_0_nblock
#
# de=5.680283922431819e-05 std(de)=4.796426685785101e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9999998807907104 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=1.935893701187716e-05 std(de)=1.588620800382903e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_6): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=80841
# R_square_test=0.9999999403953552 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_6_nconv_0_nblock
#
# de=1.536466265414708e-05 std(de)=1.142507287785876e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9999999403953552 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=1.6657029514351476e-05 std(de)=1.1503203524139184e-05

# %% [markdown]
# $R^2$

# %%
plt.plot(blocks,r,color='black',marker='o')

plt.xlabel('blocks',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.show()

# %% [markdown]
# Energy

# %%
plt.errorbar(blocks,de,yerr=devde,color='black',marker='o')
plt.semilogy()
plt.xlabel('blocks',fontsize=20)
plt.ylabel(r'$\langle \langle|e_{gs}-e_{ML}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Accuracy

# %%
ndata=100
ms = []
vs = []
g_acc = []
pseudo_pot = []
v_acc = []
models = []
for i in range(len(blocks)):
    data=np.load(data_path[i])
    m=data['density']
    v=data['potential']
    ms.append(m)
    vs.append(v)
    model=torch.load(
        "model_rep/"+models_name[i],
        map_location="cpu",
    )
    models.append(model)
    x = m[:ndata]
    x = torch.tensor(x, dtype=torch.double)
    x.requires_grad_(True)
    f = torch.mean(model(x), dim=-1)
    # print(f.shape)
    f.backward(torch.ones_like(f))
    with torch.no_grad():
        grad = x.grad
        grad = -ls[i] * grad.detach().numpy()
        pseudo_pot = grad
    # print(grad.shape)
    v_acc = np.sqrt(np.average((grad - vs[:ndata]) ** 2, axis=-1)) / np.sqrt(
        np.average((v[:ndata]) ** 2, axis=-1)
    )
    g_acc.append(
        np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
        / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
    )

g_acc = [np.average(g) for g in g_acc]

# %% [markdown]
# #### Plot

# %%
print(g_acc[0].shape)
plt.plot(blocks,g_acc,color='black',marker='o')
plt.xlabel('No. blocks',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.show()
# Out:
# ()

# %% [markdown]
# ## Scalability Performance for different Kernel Size

# %% [markdown]
# #### Data

# %%
ls=[16,24,32,64,96,108,128,136]
ls=[16,24,32,48,64]
data_path=[f'data/dataset_2nn/test_unet_periodic_2nn_{l}_l_5.44_h_1000_n.npz' for l in ls]
models_name=[#'2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_1_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock']

ks=[3,5,7,9,11]

# %% [markdown]
# #### Accuracy

# %%
rs=[]
des=[]
devdes=[]
for i in range(len(models_name)):
    r,de,devde=test_models_unet(models_name=[models_name[i]]*len(data_path),data_path=data_path)
    rs.append(r)
    des.append(de)
    devdes.append(devde)
# Out:
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9999725222587585 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.00023577858853029713 std(de)=0.0001765542341966992
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9998934268951416 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.00048546100205044854 std(de)=0.0003866747755230522
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9998464584350586 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.0005561361860523871 std(de)=0.0003465093610161994
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9997802972793579 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.000519698754462275 std(de)=0.00029940564669947103
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=9961
# R_square_test=0.9996678233146667 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_3_ks_1_ps_2_nconv_0_nblock
#
# de=0.0005234458469800023 std(de)=0.00026815155869268543
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999980330467224 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=7.422382558581005e-05 std(de)=5.902398748080983e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999584555625916 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00025725916508088974 std(de)=0.00023566322265739992
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999222755432129 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00036711228665763784 std(de)=0.00027917272540383265
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9998841285705566 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00035115071568160935 std(de)=0.0002290329277710285
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.999833345413208 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0003457927925244744 std(de)=0.00022754409521920152
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9999970197677612 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.00010849809491708991 std(de)=6.407452131262384e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9999730587005615 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.00020046531727307523 std(de)=0.000178964944976026
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9999472498893738 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.0002817427078485489 std(de)=0.00023687215683786713
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.999923050403595 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.0002604314293759949 std(de)=0.00020066115257652412
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=23081
# R_square_test=0.9998918175697327 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_7_ks_1_ps_2_nconv_0_nblock
#
# de=0.0002465834734836334 std(de)=0.0001867015980203113
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9999983310699463 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=7.072010351571671e-05 std(de)=6.069642287981778e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9999028444290161 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.0004497387799630291 std(de)=0.0003585000577208815
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9998642206192017 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.0005331199730442753 std(de)=0.0003639706170970296
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9998348951339722 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.0004086108969368197 std(de)=0.00029643654398102897
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(9,), stride=(1,), padding=(4,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=29641
# R_square_test=0.9997662901878357 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_9_ks_1_ps_2_nconv_0_nblock
#
# de=0.00040710356202152667 std(de)=0.0002694683901194812
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9999979138374329 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=7.415453600750242e-05 std(de)=6.714253654681491e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9996618032455444 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0007542082057258166 std(de)=0.0006549721804161646
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9996527433395386 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0007269935476146251 std(de)=0.0006801254997133468
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9996856451034546 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0007131733377895804 std(de)=0.0004978847114076576
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(11,), stride=(1,), padding=(5,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(11,), stride=(1,), padding=(5,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=36201
# R_square_test=0.9995956420898438 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_11_ks_1_ps_2_nconv_0_nblock
#
# de=0.0005817373859020518 std(de)=0.0004794339077326989

# %% [markdown]
# $R^2$

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.plot(ls,rs[i],marker='o',label=f'ks={ks[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.legend(fontsize=30)
plt.show()

# %% [markdown]
# Energy

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.errorbar(ls,des[i],yerr=devde,marker='o',label=f'ks={ks[i]}')
plt.legend(fontsize=20)
plt.semilogy()
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle|e_{gs}-e_{ML}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Analysis

# %%
ndata=1000
g_accs=[]
dev_g=[]
for j in range(len(models_name)):
    g_acc = []
    for i in range(len(ls)):
        data=np.load(data_path[i])
        m=data['density']
        v=data['potential']
        model=torch.load(
            "model_rep/"+models_name[j],
            map_location="cpu",
        )
        x = m[:ndata]
        x = torch.tensor(x, dtype=torch.double)
        x.requires_grad_(True)
        f = torch.mean(model(x), dim=-1)
        # print(f.shape)
        f.backward(torch.ones_like(f))
        with torch.no_grad():
            grad = x.grad
            grad = -ls[i] * grad.detach().numpy()
            pseudo_pot = grad
        # print(grad.shape)
        g_acc.append(
            np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
            / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
        )

    dev_g.append([np.std(g) for g in g_acc])
    g_acc = [np.average(g) for g in g_acc]
    g_accs.append(g_acc)

# %% [markdown]
# #### Plots

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.errorbar(ls,g_accs[i],yerr=dev_g[i],marker='o',label=f'ks={ks[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ### Gradient Descent Accuracy

# %% [markdown]
# #### Imports

# %%
import os
import time
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import dataloader, nuv_representability_check,mean_field_functional_1nn

# %% [markdown]
# #### Data

# %%
ks=[1,3,5,7,9,11]
n_sample=len(ks)
h_max=[5.44]*n_sample
ls=[16]*n_sample
n_instances=[100]*n_sample
epochs = [1900]*n_sample 
# model settings
name_session=[f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_2_layers_40_hc_{ks[i]}_ks_1_ps' for i in range(n_sample) ]

early_stopping=False
variational_lr=False
loglr=1

min_density=[]
gs_density=[]
min_energy=[]
gs_energy=[]
hs=[]

for i in range(n_sample):
    hs.append(np.load(f'data/dataset_2nn/test_unet_periodic_2nn_{ls[i]}_l_{h_max[i]}_h_100_n.npz')['potential'][0:n_instances[i]])
    min_eng_t,gs_eng_t=dataloader('energy',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    min_n_t,gs_n_t=dataloader('density',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    
    min_eng_t=np.asarray(min_eng_t)
    gs_eng_t=np.asarray(gs_eng_t)
    min_n_t=np.asarray(min_n_t)
    gs_n_t=np.asarray(gs_n_t)
    
            #if min_eng_t.shape[0]==min_eng.shape[-1]:
    min_energy.append(min_eng_t)
    gs_energy.append(gs_eng_t)
    min_density.append(min_n_t)
    gs_density.append(gs_n_t)
    
min_energy=np.asarray(min_energy)
gs_energy=np.asarray(gs_energy)
min_density=np.asarray(min_density)
gs_density=np.asarray(gs_density)

# %% [markdown]
# #### Accuracy for different ks

# %% [markdown]
# Magnetization

# %%
dz=(np.average(np.abs(gs_density-min_density),axis=-1))/np.average(np.abs(gs_density),axis=-1)

fig=plt.figure(figsize=(5,5))
plt.plot(ks,np.average(dz,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'kernel size',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta z|}{|z|} \rangle$',fontsize=30)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.semilogy()
plt.show()

# %% [markdown]
# Energy

# %%
de=np.abs(gs_energy-min_energy)/np.abs(gs_energy)

fig=plt.figure(figsize=(5,5))
plt.plot(ks,np.average(de,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'No. Blocks',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta e|}{|e|} \rangle$',fontsize=30)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.semilogy()
plt.show()

# %% [markdown]
# ## Scalability analysis at different Depth of the Neural Network

# %% [markdown]
# #### Imports

# %%
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import test_models_unet

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock',
             #'2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_6_nconv_0_nblock',
             '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock',
             ]


blocks=[1,2,3,4,5,7]
ls=[16,24,32,64,96,128]
#ls=[16,24,32,48,64]

data_path=[f'data/dataset_2nn/test_unet_periodic_2nn_{l}_l_5.44_h_100_n.npz' for l in ls]

# %% [markdown]
# #### Accuracy

# %%
rs=[]
des=[]
devdes=[]
for i in range(len(models_name)):
    r,de,devde=test_models_unet(models_name=[models_name[i]]*len(data_path),data_path=data_path)
    rs.append(r)
    des.append(de)
    devdes.append(devde)
# Out:
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9997571706771851 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.0008955248118742029 std(de)=0.0007180521350302947
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9997673034667969 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.0006983804053968218 std(de)=0.0005452594705241105
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9996859431266785 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.000798865771398334 std(de)=0.0005842253696510917
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9989383220672607 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.0009397551866266412 std(de)=0.0005825732967376298
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9984142780303955 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.0008728800350813011 std(de)=0.0006425982065406593
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=441
# R_square_test=0.9978039264678955 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40]_hc_5_ks_1_ps_1_nconv_0_nblock
#
# de=0.0009810816551735462 std(de)=0.00046023265559355555
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=6.589498515328067e-05 std(de)=6.120556790270633e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999576210975647 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00028069753444193586 std(de)=0.0002472050880889281
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999289512634277 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0003712371603527987 std(de)=0.0002928220409236292
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9995789527893066 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.000597260100691261 std(de)=0.00035782908894973467
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.999203085899353 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006242790758256296 std(de)=0.00045467493867856615
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9990535974502563 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006448328349180771 std(de)=0.00030831645291056023
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9999996423721313 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=2.809142875113842e-05 std(de)=2.8220093530883197e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9999725222587585 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.00023201787672100216 std(de)=0.0001938294255331099
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9999478459358215 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.00030891584189694706 std(de)=0.00025951840077902664
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9996428489685059 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.0005372163970910188 std(de)=0.0003496717195266262
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9993196129798889 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.0005596272957391071 std(de)=0.00044385780187864815
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_3): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=32601
# R_square_test=0.9992049932479858 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40]_hc_5_ks_1_ps_3_nconv_0_nblock
#
# de=0.0005806047224335874 std(de)=0.0003044501094114933
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999998807907104 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=1.9506001912555003e-05 std(de)=1.8074475029344446e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999713897705078 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.00023364762627797853 std(de)=0.0002014070073983414
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9999428391456604 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0003265978823433545 std(de)=0.00026845016256602395
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9996334910392761 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.000546677209597207 std(de)=0.00034993068223414573
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.999306857585907 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0005636224150560213 std(de)=0.00044885104996987405
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_4): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=48681
# R_square_test=0.9991859793663025 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40]_hc_5_ks_1_ps_4_nconv_0_nblock
#
# de=0.0005877724809570962 std(de)=0.00030726199247384776
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9999998807907104 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=1.935893701187716e-05 std(de)=1.588620800382903e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9999697208404541 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.00023994215943074163 std(de)=0.0002069000355186493
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9999375939369202 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.00034157802455382397 std(de)=0.000279399610234693
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9996160268783569 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.000562114545369866 std(de)=0.00035390318876061286
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9992769360542297 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.0005819288201770932 std(de)=0.0004503216974755854
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_5): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=64761
# R_square_test=0.9991573095321655 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40]_hc_5_ks_1_ps_5_nconv_0_nblock
#
# de=0.0006002114842110508 std(de)=0.0003081247032214997
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9999999403953552 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=1.6657029514351476e-05 std(de)=1.1503203524139184e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9999721050262451 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.0002264597973652219 std(de)=0.00020248593602930455
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9999426603317261 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.0003234998266926532 std(de)=0.0002718065038671396
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9996366500854492 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.0005400544369189384 std(de)=0.0003542263831296866
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9992997646331787 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.0005661002614864843 std(de)=0.00045141015905878054
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (conv7): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_7): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 2): GELU()
#     )
#     (2): Sequential(
#       (trans_conv3): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 3): GELU()
#     )
#     (3): Sequential(
#       (trans_conv4): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 4): GELU()
#     )
#     (4): Sequential(
#       (trans_conv5): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 5): GELU()
#     )
#     (5): Sequential(
#       (trans_conv6): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 6): GELU()
#     )
#     (6): Sequential(
#       (trans_conv7): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=96921
# R_square_test=0.9991840124130249 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40, 40, 40, 40, 40, 40]_hc_5_ks_1_ps_7_nconv_0_nblock
#
# de=0.0005868754223686313 std(de)=0.000310222555034113

# %% [markdown]
# $R^2$

# %%
plt.figure(figsize=(10,10))

for i in range(len(models_name)):
    plt.plot(ls,rs[i],marker='o',label=f'blocks={blocks[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.legend(fontsize=30)
plt.show()

# %% [markdown]
# Energy

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.errorbar(ls,des[i],yerr=devde,marker='o',label=f'blocks={blocks[i]}')
plt.legend(fontsize=20)
plt.semilogy()
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle|f_{gs}-f_{ML}|/|f_{gs}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Descent Accuracy

# %%
ndata=100
g_accs=[]
dev_g=[]
for j in range(len(models_name)):
    g_acc = []
    for i in range(len(ls)):
        data=np.load(data_path[i])
        m=data['density']
        v=data['potential']
        model=torch.load(
            "model_rep/"+models_name[j],
            map_location="cpu",
        )
        x = m[:ndata]
        x = torch.tensor(x, dtype=torch.double)
        x.requires_grad_(True)
        f = torch.mean(model(x), dim=-1)
        # print(f.shape)
        f.backward(torch.ones_like(f))
        with torch.no_grad():
            grad = x.grad
            grad = -ls[i] * grad.detach().numpy()
            pseudo_pot = grad
        # print(grad.shape)
        g_acc.append(
            np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
            / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
        )

    dev_g.append([np.std(g) for g in g_acc])
    g_acc = [np.average(g) for g in g_acc]
    g_accs.append(g_acc)

# %% [markdown]
# #### Plots

# %%
plt.figure(figsize=(10,10))
for i in range(1,len(models_name)):
    plt.errorbar(ls,g_accs[i],yerr=dev_g[i],marker='o',label=f'blocks={blocks[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.loglog()
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ### Gradient Descent Accuracy

# %% [markdown]
# #### Imports

# %%
import os
import time
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy import fft, ifft
from tqdm.notebook import tqdm, trange
from src.training.utils_analysis import dataloader, nuv_representability_check,mean_field_functional_1nn

# %% [markdown]
# #### Data

# %%
blocks=[2,3,4,5,7]

n_sample=5
h_max=[5.44]*n_sample
ls=[16]*n_sample
n_instances=[100]*n_sample
epochs = [1900]*n_sample 
# model settings
name_session=[f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_2_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_3_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_4_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_5_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_6_layers_40_hc_5_ks_1_ps',
              f'h_{h_max[0]}_15k_augmentation_2nn_model_unet_{ls[0]}_size_7_layers_40_hc_5_ks_1_ps' ]

early_stopping=False
variational_lr=False
loglr=1

min_density=[]
gs_density=[]
min_energy=[]
gs_energy=[]
hs=[]

for i in range(n_sample):
    hs.append(np.load(f'data/dataset_2nn/test_unet_periodic_2nn_{ls[i]}_l_{h_max[i]}_h_100_n.npz')['potential'][0:n_instances[i]])
    min_eng_t,gs_eng_t=dataloader('energy',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    min_n_t,gs_n_t=dataloader('density',session_name=name_session[i],n_instances=n_instances[i],lr=loglr,diff_soglia=1,epochs=epochs[i],early_stopping=False,variable_lr=False,n_ensambles=1)
    
    min_eng_t=np.asarray(min_eng_t)
    gs_eng_t=np.asarray(gs_eng_t)
    min_n_t=np.asarray(min_n_t)
    gs_n_t=np.asarray(gs_n_t)
    
            #if min_eng_t.shape[0]==min_eng.shape[-1]:
    min_energy.append(min_eng_t)
    gs_energy.append(gs_eng_t)
    min_density.append(min_n_t)
    gs_density.append(gs_n_t)
    
min_energy=np.asarray(min_energy)
gs_energy=np.asarray(gs_energy)
min_density=np.asarray(min_density)
gs_density=np.asarray(gs_density)

# %% [markdown]
# #### Accuracy for different dept

# %% [markdown]
# Magnetization

# %%
dz=(np.average(np.abs(gs_density-min_density),axis=-1))/np.average(np.abs(gs_density),axis=-1)

fig=plt.figure(figsize=(5,5))
plt.plot(blocks,np.average(dz,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'No. Blocks',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta z|}{|z|} \rangle$',fontsize=30)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.show()

# %% [markdown]
# Energy

# %%
de=np.abs(gs_energy-min_energy)/np.abs(gs_energy)

fig=plt.figure(figsize=(5,5))
plt.plot(blocks,np.average(de,axis=-1),linestyle='-',marker='o',linewidth=2,color='black')
plt.xlabel(r'No. Blocks',fontsize=30)
plt.ylabel(r'$\langle \frac{|\Delta e|}{|e|} \rangle$',fontsize=30)
plt.tick_params(
            top=True,
            right=True,
            labeltop=False,
            labelright=False,
            direction="in",
            labelsize=20,
            width=2,
        )
plt.show()

# %% [markdown]
# ## Hidden channel case

# %% [markdown]
# #### Data

# %%
models_name=['2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock',
            '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock',
            '2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock',
             ]
hc=[40,80,120]
ls=[16,24,32,64,96,108,128,136]
data_path=[f'data/dataset_2nn/test_unet_periodic_2nn_{l}_l_5.44_h_100_n.npz' for l in ls]

# %% [markdown]
# #### Accuracy

# %%
rs=[]
des=[]
devdes=[]
for i in range(len(models_name)):
    r,de,devde=test_models_unet(models_name=[models_name[i]]*len(data_path),data_path=data_path)
    rs.append(r)
    des.append(de)
    devdes.append(devde)
# Out:
# /home/ecosta/dft_for_ising/src/training/utils_analysis.py:118: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   energy = Energy_unet(model, pt.tensor(v, dtype=pt.double))
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999983906745911 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=6.589498515328067e-05 std(de)=6.120556790270633e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999576210975647 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00028069753444193586 std(de)=0.0002472050880889281
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9999289512634277 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0003712371603527987 std(de)=0.0002928220409236292
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9995789527893066 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.000597260100691261 std(de)=0.00035782908894973467
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.999203085899353 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006242790758256296 std(de)=0.00045467493867856615
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9993112683296204 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006117169990366367 std(de)=0.0003989607184928841
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9990535974502563 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006448328349180771 std(de)=0.00030831645291056023
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(40, 40, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(40, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
#   (loss_dft): MSELoss()
# )
# # parameters=16521
# R_square_test=0.9991507530212402 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[40, 40]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006375504259260482 std(de)=0.00035147839857300355
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.999998927116394 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=5.39486647495721e-05 std(de)=4.983264372116621e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9999566078186035 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0002772016008024384 std(de)=0.0002568268134940863
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9999258518218994 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00037796872192027986 std(de)=0.0002977935347612411
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.999572217464447 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0005988138838849253 std(de)=0.00036391334679263736
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9992141127586365 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006179609080990807 std(de)=0.0004542501350387468
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.999311625957489 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006127369989765346 std(de)=0.00039548072592962243
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9990586638450623 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006420380528567245 std(de)=0.00030875646290137997
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(80, 80, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(80, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=65041
# R_square_test=0.9991545081138611 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[80, 80]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006358650807299588 std(de)=0.00035118937600653473
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9999989867210388 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=5.472501940210454e-05 std(de)=4.85839781045703e-05
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9999583959579468 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0002736432399950456 std(de)=0.0002494824258560295
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9999279379844666 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.00036334589856919306 std(de)=0.0003055272479084345
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9995790123939514 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0005934838891990409 std(de)=0.0003626618695058095
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9992226362228394 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006139624708763349 std(de)=0.00045234699608571506
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9993316531181335 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006025633377936611 std(de)=0.00039169626685202683
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9990779757499695 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006342931084611697 std(de)=0.00030805351657555287
# REDENTnopooling(
#   (conv_downsample): ModuleList(
#     (0): Sequential(
#       (conv1): Conv1d(1, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (conv2): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation_2): GELU()
#     )
#   )
#   (conv_upsample): ModuleList(
#     (0): Sequential(
#       (trans_conv1): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=circular)
#       (activation 1): GELU()
#     )
#     (1): Sequential(
#       (trans_conv2): Conv1d(120, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#   )
#   (Activation): GELU()
#   (loss): MSELoss()
# )
# # parameters=145561
# R_square_test=0.9991785883903503 for 2nn_ising/h_5.44_15k_unet_periodic_augmentation_[120, 120]_hc_5_ks_1_ps_2_nconv_0_nblock
#
# de=0.0006239104006252183 std(de)=0.0003516512476294901

# %% [markdown]
# $R^2$

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.plot(ls,rs[i],marker='o',label=f'hc={hc[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$R^2$',fontsize=20)
plt.legend(fontsize=30)
plt.show()

# %% [markdown]
# Energy

# %%
plt.figure(figsize=(10,10))
for i in range(len(models_name)):
    plt.errorbar(ls,des[i],yerr=devde,marker='o',label=f'hc={hc[i]}')
plt.legend(fontsize=20)
plt.semilogy()
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle|e_{gs}-e_{ML}|/|e_{gs}| \rangle \rangle$',fontsize=20)
plt.show()

# %% [markdown]
# #### Gradient Descent Analysis

# %%
ndata=1000
g_accs=[]
dev_g=[]
for j in range(len(models_name)):
    g_acc = []
    for i in range(len(ls)):
        data=np.load(data_path[i])
        m=data['density']
        v=data['potential']
        model=torch.load(
            "model_rep/"+models_name[j],
            map_location="cpu",
        )
        x = m[:ndata]
        x = torch.tensor(x, dtype=torch.double)
        x.requires_grad_(True)
        f = torch.mean(model(x), dim=-1)
        # print(f.shape)
        f.backward(torch.ones_like(f))
        with torch.no_grad():
            grad = x.grad
            grad = -ls[i] * grad.detach().numpy()
            pseudo_pot = grad
        # print(grad.shape)
        g_acc.append(
            np.sqrt(np.average((grad - v[:ndata]) ** 2, axis=-1))
            / np.sqrt(np.average((v[:ndata]) ** 2, axis=-1))
        )

    dev_g.append([np.std(g) for g in g_acc])
    g_acc = [np.average(g) for g in g_acc]
    g_accs.append(g_acc)

# %% [markdown]
# #### Plots

# %%
plt.figure(figsize=(10,10))
for i in range(1,len(models_name)):
    plt.errorbar(ls,g_accs[i],yerr=dev_g[i],marker='o',label=f'hc={hc[i]}')
plt.xlabel(r'$l$',fontsize=20)
plt.ylabel(r'$\langle \langle |\Delta \frac{\partial F}{\partial z_i} |/|\frac{\partial F}{\partial z_i}| \rangle \rangle$',fontsize=20)
plt.loglog()
plt.legend(fontsize=20)
plt.show()
